# %%
# coding=utf-8
import sys
import random
import requests
from pymongo import MongoClient
from time import sleep
from bson import ObjectId
from selenium import webdriver
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys
import selenium.webdriver.support.ui as ui
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

# %%
api_key = '094c2420f179731334edccbf176dbd79'

# %%
def create_browser(user_agent):
    capabilities = DesiredCapabilities.FIREFOX.copy()
    capabilities['marionette'] = True
    capabilities['acceptSslCerts'] = True
    profile = webdriver.FirefoxProfile()
    profile.set_preference("browser.privatebrowsing.autostart", True)
    profile.set_preference("browser.cache.disk.enable", False)
    profile.set_preference("browser.cache.memory.enable", False)
    profile.set_preference("browser.cache.offline.enable", False)
    profile.set_preference("network.http.use-cache", False)
    profile.set_preference("general.useragent.override", user_agent['name'])
    profile.set_preference("media.volume_scale", "0.0")
    options = webdriver.FirefoxOptions()

    print(sys.platform)
    if sys.platform == 'win32':
        geckodriver = '../../etc/geckodriver-v0.21.0-win64/geckodriver.exe'
        binary = 'C:/Program Files/Mozilla Firefox/firefox.exe'
    else:
        geckodriver = 'etc/geckodriver-v0.21.0-linux64/geckodriver'
        binary = '/usr/bin/firefox'
        options.add_argument('-headless')
    driver = webdriver.Firefox(
        executable_path=geckodriver,
        firefox_options=options,
        capabilities=capabilities,
        firefox_binary=binary,
        firefox_profile=profile)
    driver.set_window_size(1920, 1080)
    driver.set_window_position(0, 0)
    return driver

# %%
def login(browser, email, password, recovery_email):
    browser.get('https://www.youtube.com/')
    WebDriverWait(browser, 30).until(EC.presence_of_element_located((By.CSS_SELECTOR, "ytd-button-renderer.style-scope:nth-child(5) > a:nth-child(1)")))
    # sign_in_btn = browser.find_element_by_css_selector('a.yt-simple-endpoint.style-scope.ytd-button-renderer')
    sign_in_btn = browser.find_element_by_css_selector('ytd-button-renderer.style-scope:nth-child(5) > a:nth-child(1)')
    sign_in_btn.click()

    WebDriverWait(browser, 30).until(EC.presence_of_element_located((By.ID, "identifierId")))
    email_inp = browser.find_element_by_id('identifierId')
    email_inp.send_keys(email)
    browser.find_element_by_id('identifierNext').click()  # đi đến trang nhập password
    sleep(3)
    WebDriverWait(browser, 30).until(EC.presence_of_element_located((By.CSS_SELECTOR, "#headingText > content")))
    heading_text = browser.find_element_by_css_selector('#headingText > content')
    if heading_text.text == 'Welcome':
        print(heading_text.text)
    else:
        return 'fail'

    WebDriverWait(browser, 30).until(EC.presence_of_element_located((By.CSS_SELECTOR, "input.whsOnd.zHQkBf")))
    password_inp = browser.find_element_by_css_selector('input.whsOnd.zHQkBf')
    password_inp.send_keys(password)
    WebDriverWait(browser, 30).until(EC.presence_of_element_located((By.ID, "passwordNext")))
    browser.find_element_by_id('passwordNext').click()
    
    sleep(2)
    # Input recovery email
    try:
        WebDriverWait(browser, 30).until(EC.presence_of_element_located((By.ID, "headingText")))
        header = browser.find_element_by_id('headingText')
        if header and header.text == 'Verify it\'s you':
            print('Need to input recovery email')
            browser.find_element_by_class_name('vdE7Oc').click()
            sleep(2)
            while True:
                try:
                    recovery_inp = browser.find_element_by_id('knowledge-preregistered-email-response')
                    recovery_inp.click()
                    recovery_inp.send_keys(recovery_email)
                    break
                except:
                    print('Input recovery email')

            next_btn = browser.find_element_by_id('next')
            browser.execute_script("arguments[0].click();", next_btn)
    except Exception as ex:
        print('No need to enter recovery email')
        return 'success'
    
    sleep(2)
    try:
        # check protected account
        WebDriverWait(browser, 10).until(EC.presence_of_element_located((By.CLASS_NAME, "N4lOwd")))
        title = browser.find_element_by_class_name('N4lOwd')
        print(title.text)
        if title and title.text == 'Protect your account':
            done_btn = browser.find_element_by_class_name('CwaK9')
            done_btn.click()
    except Exception as ex:
        pass
    
    sleep(2)
    try:
        WebDriverWait(browser, 10).until(EC.presence_of_element_located((By.ID, "headingText")))
        header = browser.find_element_by_id('headingText')
        print(header.text)
        if header and (header.text == 'Account disabled' or header.text == 'Change password'):
            return 'disabled'
    except Exception as ex:
        print('Enter recovery email successfully')
        
    try:
        ui.WebDriverWait(browser, 10).until(EC.url_matches('https://www.youtube.com'))
        return 'success'
    except Exception as ex:
        return 'fail'

# %%
def get_key_recaptcha(browser, xpath):
    try:
        browser.switch_to.default_content()
        iframe = browser.find_element_by_xpath(xpath)
        key = iframe.get_attribute('src')
        keys = key.split('&')
        for item in keys:
            if 'k=' in item:
                key = item[2:]
                return key
    except Exception as ex:
        print('Can not switch to recaptcha checkbox: {}'.format(str(ex)))
        return None


def key_resolver_captcha(api_url):
    try:
        r = requests.get(api_url)
        res = r.text
        if 'OK' in res:
            request_id = res[3:]
            resolver_api = 'http://2captcha.com/res.php?key={}&action=get&id={}'.format(api_key, request_id)
            print(resolver_api)
            while True:
                try:
                    response = requests.get(resolver_api)
                    response = response.text
                    if 'OK' in response:
                        response_key = response[3:]
                        break
                    if 'ERROR_CAPTCHA_UNSOLVABLE' in response:
                        response_key = None
                        break
                    sleep(5)
                except Exception as ex:
                    print('Get response error: {}'. format(str(ex)))

            return response_key
        else:
            print('Can not get key api 2captcha.com')
    except Exception as ex:
        print('Can not resolver captcha: {}'.format(str(ex)))
        return None

# %%
def change_language(browser):
    try:
        lang_btn = browser.find_element_by_id('yt-picker-language-button')
        lang_btn.click()
        sleep(2)
        langs = browser.find_elements_by_css_selector('.yt-picker-item > span')
        for lang in langs:
            if 'English' in lang.text:
                lang.click()
                return
    except Exception as ex:
        print('Change lang failed: {}'.format(str(ex)))

# %%
def videos_of_channel(browser):
    channels = db.channel.find({'status': 'active'})
    channels = list(channels)
    if len(channels) == 0:
        print('Channel list is empty')
        return
    channel = random.choice(channels)
    browser.get('{}/videos'.format(channel['channel']))
    channel_id = channel['_id']
    videos = browser.find_elements_by_id('video-title')
    data = list()
    for video in videos:
        href = video.get_attribute('href')
        if not href.startswith('https'):
            href = 'https://www.youtube.com/{}'.format(href)
        data.append({'url': href, 'title': video.text})
    return data, channel_id

# %%
def fake_user_profile():
    pass

# %%
def stat_report_user():
    login_status = False
    videos = list()
    channels = db.channel.find({'status': 'active'})
    channels = list(channels)
    if len(channels) == 0:
        print('Channel list is empty')
        return
    channel = random.choice(channels)

    while not login_status:
        tmp_emails = db.email.find({'status': True})
        tmp_emails = list(tmp_emails)
        if len(tmp_emails) == 0:
            print('Can not find any email')
            return
        tmp_email = random.choice(tmp_emails)
        email = tmp_email['email']
        password = tmp_email['password']
        recovery_email = tmp_email['recovery_email']
        login_status = login(email, password, recovery_email)
        if login_status == 'success':
            print('Logged in to youtube')
        elif login_status == 'fail':
            print('{} can not login to youtube'.format(email))
            browser.quit()
            return
        elif login_status == 'disabled':
            print('{} is disabled'.format(email))
            db.email.update({'_id': tmp_email['_id']}, {'$set': {'status': False}})
            browser.quit()
            return

    try:
        if channel is not None:
            db.channel.update({'_id': channel['_id']}, {'$set': {'reporting': True}})
            print(channel['name'])
            strategy = db.strategy.find_one({'_id': ObjectId(channel['strategy'])})
            if strategy is not None:
                report_reason_1 = strategy['issue']
                report_reason_2 = strategy['sub_issue']
                report_note = strategy['note']
                report_channel = channel['channel']

                # report three times
                for i in range(3):
                    submit_report_status = submit_report(
                        report_channel,
                        report_reason_1, report_reason_2,
                        report_note)

                    if submit_report_status == '1':
                        x_path = '/html/body/div[1]/form/div/div/div/iframe'
                        google_key = get_key_recaptcha(x_path)
                        if google_key is None:
                            db.channel.update({'_id': channel['_id']}, {'$inc': {'count_fail': 1}})

                        current_url = browser.current_url
                        captcha_resolver_api = 'http://2captcha.com/in.php?key={}&method=userrecaptcha&googlekey={}&pageurl={}&here=now'.format(
                            api_key, google_key, current_url)
                        key_resolver = key_resolver_captcha(captcha_resolver_api)
                        if key_resolver is not None:

                            browser.switch_to.default_content()
                            WebDriverWait(browser, 30).until(
                                EC.presence_of_element_located((By.ID, "g-recaptcha-response")))
                            browser.execute_script(
                                "document.getElementById('g-recaptcha-response').style.display = 'block';")
                            textarea_box = browser.find_element_by_id('g-recaptcha-response')
                            textarea_box.send_keys(key_resolver)
                            submit_report_btn = browser.find_element_by_id('submit-report')
                            submit_report_btn.click()
                            try:
                                WebDriverWait(browser, 30).until(
                                    EC.presence_of_element_located((By.CSS_SELECTOR, ".section > p:nth-child(1)")))
                                section = browser.find_element_by_css_selector('.section > p:nth-child(1)')
                                if section and section.text == 'Thank You.':
                                    print('Submit report successfully')
                                    db.channel.update({'_id': channel['_id']},
                                                             {'$inc': {'count_success': 1}})
                            except Exception as ex:
                                print('Submit report failed: {}'.format(str(ex)))
                                db.channel.update({'_id': channel['_id']}, {'$inc': {'count_fail': 1}})

                        else:
                            db.channel.update({'_id': channel['_id']}, {'$inc': {'count_fail': 1}})

                    elif submit_report_status == '2':
                        print('Channel suspended save to database')
                        db.channel.update({'_id': channel['_id']}, {'$set': {'status': 'Suspended'}})
                        return
                db.channel.update({'_id': channel['_id']}, {'$set': {'reporting': False}})

    except Exception as ex:
        db.channel.update({'_id': channel['_id']}, {'$set': {'reporting': False}})
        print('Exception: {}'.format(str(ex)))

# %%
def main_func(browser, db):
    channel_id = None
    login_status = False
    while not login_status:
        tmp_emails = db.email.find({'status': True})
        tmp_emails = list(tmp_emails)
        if len(tmp_emails) == 0:
            print('Can not find any email')
            return
        tmp_email = random.choice(tmp_emails)
        email = tmp_email['email']
        password = tmp_email['password']
        recovery_email = tmp_email['recovery_email']
        login_status = login(browser, email, password, recovery_email)
        if login_status == 'success':
            print('Logged in to youtube')
        elif login_status == 'fail':
            print('{} can not login to youtube'.format(email))
            browser.quit()
            return
        elif login_status == 'disabled':
            print('{} is disabled'.format(email))
            db.email.update({'_id': tmp_email['_id']}, {'$set': {'status': False}})
            browser.quit()
            return
    videos, channel_id = videos_of_channel(browser)
    for video in videos:
        browser.get('https://www.youtube.com/copyright_complaint_form')
        try:
            title = browser.find_element_by_xpath('/html/body/div[1]/div/b')
            if title.text == 'About this page':
                x_path = '/html/body/div[1]/form/div/div/div/iframe'
                google_key = get_key_recaptcha(browser, x_path)
                current_url = browser.current_url
                captcha_resolver_api = 'http://2captcha.com/in.php?key={}&method=userrecaptcha&googlekey={}&pageurl={}&here=now'.format(api_key, google_key, current_url)
                key_resolver = key_resolver_captcha(captcha_resolver_api)
                if key_resolver is not None:
                    browser.switch_to.default_content()
                    WebDriverWait(browser, 30).until(
                        EC.presence_of_element_located((By.ID, "g-recaptcha-response")))
                    browser.execute_script(
                        "document.getElementById('g-recaptcha-response').style.display = 'block';")
                    textarea_box = browser.find_element_by_id('g-recaptcha-response')
                    textarea_box.send_keys(key_resolver)
                    submit_report_btn = browser.find_element_by_xpath('/html/body/div[1]/form/input[3]')
                    submit_report_btn.click()
        except Exception as ex:
            print('No Need to resolver captcha')

        change_language(browser)
        reason1 = 'copyright infringement (someone copied my creation)'
        reason2 = 'i am!'

        complaint_filter_div = browser.find_element_by_id('complaint_filter_div')
        complaints = complaint_filter_div.find_elements_by_css_selector('ul > li > label')
        for complaint in complaints:
            complaint_text = complaint.text
            complaint_text = complaint_text.lower().strip()
            if complaint_text == reason1:
                complaint.click()

        affected_entities_div = browser.find_element_by_id('affected-entities-div')
        complaints = affected_entities_div.find_elements_by_css_selector('ul > li > label')
        for complaint in complaints:
            complaint_text = complaint.text
            complaint_text = complaint_text.lower().strip()
            if complaint_text == reason2:
                complaint.click()

        video_url_0 = browser.find_element_by_id('video_url_0')
        video_url_0.send_keys(video['url'])
        from selenium.webdriver.support.ui import Select
        issue_type_0 = Select(browser.find_element_by_id('issue_type_0'))
        issue_type_0.select_by_value('S')

        issue_details_wrapper = browser.find_element_by_class_name('issue_details_wrapper')
        conditional_value_validations = issue_details_wrapper.find_elements_by_css_selector('.conditional-value-validation')
        for conditional_value_validation in conditional_value_validations:
            if conditional_value_validation.get_attribute('name') == 'issue_detail_S_0':
                conditional_value_validation.send_keys(video['title'])

        reason3 = 'entire video'
        position_marker = browser.find_element_by_class_name('position-marker-class-S-0')
        issue_details = position_marker.find_elements_by_css_selector('ul > li > label')
        for issue_detail in issue_details:
            issue_detail_text = issue_detail.text
            issue_detail_text = issue_detail_text.lower().strip()
            if issue_detail_text == reason3:
                issue_detail.click()

        totals = db.fake_user.count_documents({})
        fake_user = db.fake_user.find({}).limit(-1).skip(random.randint(0, totals)).next()

        owner_display_name = browser.find_element_by_id('owner_display_name')
        owner_display_name.send_keys(fake_user['name'])

        requester_title = browser.find_element_by_id('requester_title')
        requester_title.send_keys(fake_user['name'])

        requester_name = browser.find_element_by_id('requester_name')
        requester_name.send_keys(fake_user['name'])

        address1 = browser.find_element_by_id('address1')
        address1.send_keys(fake_user['address_1'])

        address2 = browser.find_element_by_id('address2')
        address2.send_keys(fake_user['address_2'])

        city = browser.find_element_by_id('city')
        city.send_keys(fake_user['city'])

        state = browser.find_element_by_id('state')
        state.send_keys(fake_user['state'])

        zip_code = browser.find_element_by_id('zip')
        zip_code.send_keys(fake_user['zip_code'])

        phone = browser.find_element_by_id('phone')
        phone.send_keys(fake_user['phone'])

        country = Select(browser.find_element_by_id('country'))
        country.select_by_value('US')

        browser.find_element_by_id('checkbox_confirmation_1').click()
        browser.find_element_by_id('checkbox_confirmation_2').click()
        browser.find_element_by_id('checkbox_confirmation_3').click()
        browser.find_element_by_id('checkbox_confirmation_liability').click()
        browser.find_element_by_id('checkbox_confirmation_abuse_termination').click()
        owner_signature = browser.find_element_by_id('owner_signature')
        owner_signature.send_keys(fake_user['name'])

        iframe_path = '/html/body/div[1]/div[3]/div/div/div[2]/form/div[5]/div[4]/div/div/iframe'
        google_key = get_key_recaptcha(browser, iframe_path)
        current_url = browser.current_url
        captcha_resolver_api = 'http://2captcha.com/in.php?key={}&method=userrecaptcha&googlekey={}&pageurl={}&here=now'.format(
            api_key, google_key, current_url)
        key_resolver = key_resolver_captcha(captcha_resolver_api)
        if key_resolver is not None:
            browser.switch_to.default_content()
            WebDriverWait(browser, 30).until(
                EC.presence_of_element_located((By.ID, "g-recaptcha-response")))
            browser.execute_script(
                "document.getElementById('g-recaptcha-response').style.display = 'block';")
            textarea_box = browser.find_element_by_id('g-recaptcha-response')
            textarea_box.send_keys(key_resolver)
            submit_report_btn = browser.find_element_by_id('submit_complaint_button')
            submit_report_btn.click()
            try:
                change_language(browser)
                content = browser.find_element_by_css_selector('.page-default > div > h1')
                if content and 'Thank you' in content.text:
                    print('Submit report successfully')
                    db.channel.update({'_id': channel_id}, {'$inc': {'count_success': 1}})
            except Exception as ex:
                print('Submit report failed: {}'.format(str(ex)))
                db.channel.update({'_id': channel_id}, {'$inc': {'count_fail': 1}})
    browser.quit()

# %%
while True:
    try:
        client = MongoClient('167.99.145.231', username='admin', password='1234567a@', authSource='admin')
        db = client['test-yt']
        totals = db.agents.count_documents({'status': True})
        agent = db.agents.find({'status': True}).limit(-1).skip(random.randint(0, totals)).next()
        print(agent['name'])
        browser = create_browser(agent)
        main_func(browser, db)
    except Exception as ex:
        browser.quit()
        print('Exception: {}'.format(str(ex)))
# Out:
# Mozilla/5.0 (Windows NT 6.2; WOW64; rv:48.0) Gecko/20100101 Firefox/48.0
# win32
# Welcome
# Need to input recovery email
# Account disabled
# haiyenb56@gmail.com is disabled
# C:\Users\Thinh\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: DeprecationWarning: update is deprecated. Use replace_one, update_one or update_many instead.
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5) AppleWebKit/601.5.17 (KHTML, like Gecko) Version/9.1 Safari/537.86.5
# win32
# Welcome
# Need to input recovery email
# Change password
# vungocb65@gmail.com is disabled
# Mozilla/5.0 (Windows NT 6.2; WOW64; rv:53.0) Gecko/20100101 Firefox/53.0
# win32
# Welcome
# Need to input recovery email
# Account disabled
# daulonb54@gmail.com is disabled
# Mozilla/5.0 (X11; Ubuntu; Linux i686; rv:49.0) Gecko/20100101 Firefox/49.0
# win32
# Welcome
# Need to input recovery email
# Account disabled
# minlinhb65@gmail.com is disabled
# Mozilla/5.0 (X11; Linux i686; rv:48.0) Gecko/20100101 Firefox/48.0 Light/48.0
# win32
# Exception: 167.99.145.231:27017: [WinError 10053] An established connection was aborted by the software in your host machine
# Mozilla/5.0 (X11; Linux i686; rv:61.0) Gecko/20100101 Firefox/61.0
# win32
# Welcome
# Need to input recovery email
# Protect your account
# Enter recovery email successfully
# Logged in to youtube
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448083347
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448085749
# Submit report successfully
# C:\Users\Thinh\Anaconda3\lib\site-packages\ipykernel_launcher.py:153: DeprecationWarning: update is deprecated. Use replace_one, update_one or update_many instead.
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448089667
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448105237
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448107715
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448113826
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448119021
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448122684
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448128068
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
# C:\Users\Thinh\Anaconda3\lib\site-packages\ipykernel_launcher.py:156: DeprecationWarning: update is deprecated. Use replace_one, update_one or update_many instead.
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448132168
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448135334
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448139004
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448141968
# Submit report successfully
# No Need to resolver captcha
# Exception: Message: Unable to locate element: [id="complaint_filter_div"]
#
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.11; rv:60.0) Gecko/20100101 Firefox/60.0
# win32
# Welcome
# No need to enter recovery email
# Logged in to youtube
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448151239
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448153985
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448156260
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448161046
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448163454
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448172571
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448177029
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448181750
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448184835
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448197028
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448200963
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448207938
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448211556
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448214951
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448229857
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448234356
# Submit report successfully
# No Need to resolver captcha
# Exception: Message: Unable to locate element: [id="complaint_filter_div"]
#
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/38.0.2125.122 Safari/537.36 OPR/25.0.1614.71
# win32
# Welcome
# Enter recovery email successfully
# Logged in to youtube
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448245285
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448248251
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448251678
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448259977
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448264388
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448270433
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448274680
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448279817
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448286443
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448288990
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448295512
# Get response error: HTTPConnectionPool(host='2captcha.com', port=80): Max retries exceeded with url: /res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448295512 (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x0000028CF4B3F358>: Failed to establish a new connection: [WinError 10053] An established connection was aborted by the software in your host machine',))
# Get response error: HTTPConnectionPool(host='2captcha.com', port=80): Max retries exceeded with url: /res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448295512 (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x0000028CF4B40EB8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',))
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448300502
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448306140
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448309461
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448311351
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448320524
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448322289
# Submit report successfully
# No Need to resolver captcha
# Exception: Message: Unable to locate element: [id="complaint_filter_div"]
#
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_0; managedpc) AppleWebKit/601.6.17 (KHTML, like Gecko) Version/9.1 Safari/601.6.17
# win32
# Welcome
# Need to input recovery email
# Protect your account
# Enter recovery email successfully
# tren27nha@gmail.com can not login to youtube
# Mozilla/5.0 (Windows NT 6.3; WOW64; rv:47.0) Gecko/20100101 Firefox/47.0
# win32
# Welcome
# Need to input recovery email
# Enter recovery email successfully
# Logged in to youtube
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448338938
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448345154
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448349013
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448353272
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448355700
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448360034
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448365250
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448369192
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448378083
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448381544
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448397399
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448399909
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448402785
# Submit report successfully
# No Need to resolver captcha
# Exception: Message: Unable to locate element: [id="complaint_filter_div"]
#
# Mozilla/5.0 (X11; Linux x86_64; rv:56.0) Gecko/20100101 Firefox/56.0 Waterfox/56.0
# win32
# Welcome
# No need to enter recovery email
# Logged in to youtube
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448410633
# Get response error: HTTPConnectionPool(host='2captcha.com', port=80): Max retries exceeded with url: /res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448410633 (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x0000028CF4B87518>: Failed to establish a new connection: [WinError 10053] An established connection was aborted by the software in your host machine',))
# Get response error: HTTPConnectionPool(host='2captcha.com', port=80): Max retries exceeded with url: /res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448410633 (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x0000028CF4B7C748>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',))
# Exception: Message: Unable to locate element: [id="complaint_filter_div"]
#
# Mozilla/5.0 (X11; Linux x86_64; rv:44.0) Gecko/20100101 Firefox/44.0 Iceweasel/44.0.2
# win32
# Exception: Message:
#
# Mozilla/5.0 (X11; Linux i686; rv:58.0) Gecko/20100101 Firefox/58.0
# win32
# Welcome
# Need to input recovery email
# Account disabled
# thocanv43@gmail.com is disabled
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5) AppleWebKit/602.1.50 (KHTML, like Gecko) Version/10.0 Safari/602.1.50
# win32
# Welcome
# Need to input recovery email
# No need to enter recovery email
# Logged in to youtube
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448421721
# Change lang failed: Message: Unable to locate element: [id="yt-picker-language-button"]
#
# Exception: Message: Unable to locate element: [id="complaint_filter_div"]
#
# Mozilla/5.0 (Windows NT 6.2; WOW64; rv:44.0) Gecko/20100101 Firefox/44.0
# win32
# Welcome
# Need to input recovery email
# Enter recovery email successfully
# Logged in to youtube
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448433323
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448437056
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448441828
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448445665
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448447932
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448452873
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448457523
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448461693
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448466570
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448469211
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448477922
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448482445
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448488070
# Submit report successfully
# No Need to resolver captcha
# Exception: Message: Unable to locate element: [id="complaint_filter_div"]
#
# Mozilla/5.0 (Windows NT 5.1; WOW64; rv:54.0) Gecko/20100101 Firefox/54.0
# win32
# Welcome
# Need to input recovery email
# Enter recovery email successfully
# Logged in to youtube
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448496668
# Change lang failed: Message: Unable to locate element: [id="yt-picker-language-button"]
#
# Exception: Message: Unable to locate element: [id="complaint_filter_div"]
#
# Mozilla/5.0 (X11; Linux x86_64; rv:46.0) Gecko/20100101 Firefox/46.0
# win32
# Welcome
# Need to input recovery email
# Change password
# thanhuyenb42@gmail.com is disabled
# Mozilla/5.0 (X11; Ubuntu; Linux i686; rv:21.0) Gecko/20100101 Firefox/48.0
# win32
# Welcome
# Welcome
# tren09nha@gmail.com can not login to youtube
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/601.7.8 (KHTML, like Gecko) Version/10.0.2 Safari/602.3.12
# win32
# Welcome
# Need to input recovery email
# Protect your account
# Enter recovery email successfully
# tren44nha@gmail.com can not login to youtube
# Mozilla/5.0 (X11; Fedora; Linux x86_64; rv:44.0) Gecko/20100101 Firefox/44.0
# win32
# Welcome
# Need to input recovery email
# Protect your account
# Enter recovery email successfully
# tren32nha@gmail.com can not login to youtube
# Mozilla/5.0 (Windows NT 6.2; WOW64; rv:51.0) Gecko/20100101 Firefox/51.0
# win32
# Welcome
# No need to enter recovery email
# Logged in to youtube
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448532642
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448536547
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448540354
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448543680
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448545730
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448551672
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448555572
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448559043
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448562988
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448571938
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448577474
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448582689
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448587299
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448593313
# Submit report successfully
# No Need to resolver captcha
# Exception: Message: Unable to locate element: [id="complaint_filter_div"]
#
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/601.6.17 (KHTML, like Gecko) Version/9.1.1 Safari/601.6.17
# win32
# Welcome
# No need to enter recovery email
# Logged in to youtube
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448599568
# Exception: Message: Element <label> could not be scrolled into view
#
# Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0
# win32
# Welcome
# Need to input recovery email
# Account disabled
# ngohuongbd27@gmail.com is disabled
# Mozilla/5.0 (X11; Ubuntu; Linux i686; rv:46.0) Gecko/20100101 Firefox/46.0
# win32
# Welcome
# No need to enter recovery email
# Logged in to youtube
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448613624
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448616371
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448620107
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448625301
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448629172
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448634786
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448640037
# Get response error: ('Connection aborted.', ConnectionAbortedError(10053, 'An established connection was aborted by the software in your host machine', None, 10053, None))
# Change lang failed: Message: Unable to locate element: [id="yt-picker-language-button"]
#
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# Can not switch to recaptcha checkbox: Message: Unable to locate element: /html/body/div[1]/form/div/div/div/iframe
#
# Can not get key api 2captcha.com
# Change lang failed: Message: Unable to locate element: [id="yt-picker-language-button"]
#
# Exception: Message: Unable to locate element: [id="complaint_filter_div"]
#
# Mozilla/5.0 (X11; Ubuntu; Linux i686; rv:51.0) Gecko/20100101 Firefox/51.0
# win32
# Welcome
# No need to enter recovery email
# Logged in to youtube
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448648982
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448651818
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448655883
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448663176
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448666195
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448669579
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448673052
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448675607
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448678526
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448682523
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448685201
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448688100
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448691975
# Submit report successfully
# No Need to resolver captcha
# Exception: Message: Unable to locate element: [id="complaint_filter_div"]
#
# Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/48.0.2564.82 Safari/537.36 OPR/35.0.2066.37
# win32
# Welcome
# Need to input recovery email
# Account disabled
# lantueb32@gmail.com is disabled
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5) AppleWebKit/600.8.9 (KHTML, like Gecko) Version/9.1.2 Safari/601.7.7
# win32
# Welcome
# Need to input recovery email
# Enter recovery email successfully
# Logged in to youtube
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448707687
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448710790
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448714230
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448724723
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448731780
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448735626
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448740470
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448742791
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448747427
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448749664
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448752506
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448756868
# Submit report successfully
# No Need to resolver captcha
# Exception: Message: Unable to locate element: [id="complaint_filter_div"]
#
# Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.85 Safari/537.36 OPR/32.0.1948.25
# win32
# Welcome
# Need to input recovery email
# Account disabled
# lanvub42@gmail.com is disabled
# Mozilla/5.0 (Windows NT 10.0; WOW64; rv:61.0) Gecko/20100101 Firefox/61.0
# win32
# Welcome
# Need to input recovery email
# Enter recovery email successfully
# Logged in to youtube
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448772930
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448775801
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448780651
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448785191
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448788614
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448795192
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448803299
# Get response error: HTTPConnectionPool(host='2captcha.com', port=80): Max retries exceeded with url: /res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448803299 (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x0000028CF4B4C7F0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',))
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448806955
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448809598
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448813463
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448816861
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448821876
# Submit report successfully
# No Need to resolver captcha
# Exception: Message: Unable to locate element: [id="complaint_filter_div"]
#
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5) AppleWebKit/601.2.7 (KHTML, like Gecko) Version/9.0.1 Safari/601.2.7
# win32
# Welcome
# No need to enter recovery email
# Logged in to youtube
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448830647
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448833382
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448845381
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448849528
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448853842
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448860316
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448866604
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448869072
# Get response error: HTTPConnectionPool(host='2captcha.com', port=80): Max retries exceeded with url: /res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448869072 (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x0000028CF4B91B38>: Failed to establish a new connection: [WinError 10053] An established connection was aborted by the software in your host machine',))
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448874217
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448879681
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448884879
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448895670
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448901929
# Submit report successfully
# No Need to resolver captcha
# Exception: Message: Unable to locate element: [id="complaint_filter_div"]
#
# Mozilla/5.0 (Windows NT 6.3; rv:57.0) Gecko/20100101 Firefox/57.0
# win32
# Welcome
# Need to input recovery email
# Enter recovery email successfully
# Logged in to youtube
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448909110
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448920745
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448932056
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448945367
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448953398
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448960017
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448962885
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448971373
# Get response error: HTTPConnectionPool(host='2captcha.com', port=80): Max retries exceeded with url: /res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448971373 (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x0000028CF4B3F630>: Failed to establish a new connection: [WinError 10053] An established connection was aborted by the software in your host machine',))
# Get response error: HTTPConnectionPool(host='2captcha.com', port=80): Max retries exceeded with url: /res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448971373 (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x0000028CF4B76128>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',))
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448979921
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448982870
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448985355
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60448990537
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449001940
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449007673
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449011192
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449016099
# Submit report successfully
# No Need to resolver captcha
# Exception: Message: Unable to locate element: [id="complaint_filter_div"]
#
# Mozilla/5.0 (Linux) (x64) (rv:) Gecko/20100101 Firefox/50.0
# win32
# Welcome
# Need to input recovery email
# Account disabled
# themhieub32@gmail.com is disabled
# Mozilla/5.0 (Windows NT 6.2; Win64; x64; rv:58.0) Gecko/20100101 Firefox/58.0
# win32
# Welcome
# Need to input recovery email
# Account disabled
# bittanb45@gmail.com is disabled
# Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36 Edge/16.16299
# win32
# Welcome
# Need to input recovery email
# Enter recovery email successfully
# Logged in to youtube
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449034771
# Change lang failed: Message: Unable to locate element: [id="yt-picker-language-button"]
#
# Exception: Message: Unable to locate element: [id="complaint_filter_div"]
#
# Mozilla/5.0 (X11; Linux x86_64; rv:10.0) Gecko/20150101 Firefox/44.0 (Chrome)
# win32
# Welcome
# No need to enter recovery email
# Logged in to youtube
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449042235
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449047682
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449050808
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449064386
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449070065
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449082464
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449086475
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449100749
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449106274
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449113185
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449117173
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449119843
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449125914
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449128069
# Submit report successfully
# No Need to resolver captcha
# Exception: Message: Unable to locate element: [id="complaint_filter_div"]
#
# Mozilla/5.0 (X11; Linux x86_64; rv:56.0) Gecko/20100101 Firefox/56.0 Waterfox/56.0
# win32
# Welcome
# Need to input recovery email
# Enter recovery email successfully
# Logged in to youtube
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449136365
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449138836
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449144124
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449146616
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449151240
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449154705
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449158393
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449161251
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449165387
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449178406
# Submit report failed: Message: Unable to locate element: .page-default > div > h1
#
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449182679
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449193564
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449196761
# Submit report successfully
# No Need to resolver captcha
# Exception: Message: Unable to locate element: [id="complaint_filter_div"]
#
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.11; rv:55.0) Gecko/20100101 Firefox/55.0
# win32
# Welcome
# Need to input recovery email
# Account disabled
# tiendungv54@gmail.com is disabled
# Mozilla/6.0 (Windows NT 7.2; WOW64; rv:45.0) Gecko/20100101 Firefox/45.0
# win32
# Welcome
# Need to input recovery email
# Enter recovery email successfully
# Logged in to youtube
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449204817
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449207446
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449210634
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449219547
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449222309
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449224495
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449228419
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449234797
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449237308
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449239460
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449241890
# Submit report successfully
# No Need to resolver captcha
# Exception: Message: Unable to locate element: [id="complaint_filter_div"]
#
# Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:54.0) Gecko/20100101 Firefox/54.0
# win32
# Welcome
# Need to input recovery email
# Enter recovery email successfully
# Logged in to youtube
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449246763
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449249294
# Submit report successfully
# No Need to resolver captcha
# http://2captcha.com/res.php?key=094c2420f179731334edccbf176dbd79&action=get&id=60449252016
# Submit report successfully
# No Need to resolver captcha
